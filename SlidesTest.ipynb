# %% [markdown]
# # This is a test to see if I can get Jupyter slides working on Github

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#This is some code to make some data
xdat=np.arange(0,100,1)
ydat=10.1345*xdat+50*np.random.uniform(-1.0,1.0,100)

# %%
plt.plot(xdat,ydat)
plt.show()
